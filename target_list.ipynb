# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from astroquery.mast import Catalogs

# %%
tl = Catalogs.query_criteria(catalog="Tic",objType="STAR",Teff=[0,6000],sector=[0,13])
# Out:
# WARNING: InputWarning: Filter sector does not exist. This filter will be skipped. [astroquery.mast.discovery_portal]
#
# KeyboardInterrupt

# %%
tl
# Out:
# <Table masked=True length=13>
#     ID    version   HIP  TYC     UCAC    ...     e_RA_orig          e_Dec_orig     raddflag wdflag   objID
#    str9     str8   int64 str1   str10    ...      float64            float64        int64   int64    str10
# --------- -------- ----- ---- ---------- ... ------------------ ------------------ -------- ------ ----------
#  94322581 20190415    --   --         -- ...  0.230275083633121  0.205286802302475        1      0  606092549
# 463721073 20190415    --   --         -- ...  0.447533562779131  0.489828592248652       -1      1  710312391
# 282391528 20190415    --   --         -- ...  0.360758899555407   0.47766300834538        0      0  574723760
# 123585000 20190415    --   --         -- ...  0.489499354802987  0.618316068787371        0      0  574511442
#  64575709 20190415    --   --         -- ...  0.281471137569143   0.21969663115091        1      0  595775997
# ...
