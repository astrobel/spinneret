# %%
import numpy as np
import lightkurve as lk
import matplotlib.pyplot as plt
import scipy.signal as sps
import exoplanet as ex
from tessifystarspot import *

# %%
lc = lk.search_lightcurve('KIC 1865663', quarter=9).download(quality_bitmask=0) #.remove_outliers()
# lc = lk.search_lightcurve('KIC 1026146', quarter=9).download().remove_outliers()

# %%
len(np.nonzero(lc.quality.value)[0])
# Out:
# 315

# %%
np.nonzero(lc.quality.value)[0]
# Out:
# array([  10,   14,   18,   19,   27,   43,   61,   66,   91,   96,  103,
#         104,  105,  106,  107,  108,  115,  116,  117,  118,  182,  215,
#         225,  249,  250,  277,  278,  280,  321,  324,  332,  396,  397,
#         407,  422,  440,  464,  512,  515,  519,  532,  542,  550,  563,
#         571,  605,  641,  644,  688,  698,  789,  834,  835,  896,  897,
#         918,  940,  980,  985, 1042, 1043, 1045, 1053, 1126, 1137, 1151,
#        1161, 1251, 1272, 1304, 1309, 1310, 1326, 1345, 1358, 1359, 1360,
#        1362, 1377, 1395, 1397, 1400, 1418, 1419, 1479, 1481, 1496, 1497,
#        1498, 1504, 1519, 1524, 1564, 1575, 1582, 1589, 1592, 1619, 1622,
#        1624, 1661, 1669, 1710, 1711, 1712, 1713, 1722, 1724, 1754, 1762,
#        1768, 1771, 1777, 1784, 1796, 1799, 1821, 1828, 1864, 1895, 1935,
#        1959, 1960, 2014, 2035, 2041, 2042, 2043, 2044, 2045, 2068, 2129,
#        2139, 2157, 2187, 2197, 2257, 2296, 2333, 2334, 2344, 2479, 2513,
# ...

# %%
lc.time[3770]
# Out:
# <Time object: scale='tdb' format='bkjd' value=886.8821618201473>

# %%
# %matplotlib notebook
lc.plot()
# Out:
# <img src="data:image/png;base64,..." width="848">
# <AxesSubplot:xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>
